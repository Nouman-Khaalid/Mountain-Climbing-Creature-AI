# %% [markdown]
# # Dependencies

# %%
# !pip install pybullet

# %% [markdown]
# # for directory check

# %%
# !ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 1552 Jul  6 19:03 Creature.py
# -rw-r--r-- 1 root root 3446 Jul  6 19:03 cw-envt.py
# -rw-r--r-- 1 root root 1853 Jul  6 19:03 fitness.py
# drwxr-xr-x 2 root root 4096 Jul  6 18:52 __pycache__
# drwxr-xr-x 1 root root 4096 Jul  3 13:21 sample_data

# %% [markdown]
# # output

# %%
# !python cw-envt.py
# Out:
# pybullet build time: Nov 28 2023 23:45:17
# Generation 0
# Position after move: (-0.3550071461374256, 0.016260766172584037, 0.012059690479216158)
# Creature at (-0.3550071461374256, 0.016260766172584037, 0.012059690479216158) with fitness: -14.384066445958753
# Position after move: (-0.5468179060701603, 0.013405961874704657, 0.009808702630986491)
# Creature at (-0.5468179060701603, 0.013405961874704657, 0.009808702630986491) with fitness: -14.524721155215653
# Position after move: (-0.5859371137887395, -0.005011233632662921, -0.0037527452315897505)
# Creature at (-0.5859371137887395, -0.005011233632662921, -0.0037527452315897505) with fitness: -14.56579309359097
# Position after move: (-0.465649130142731, -0.03441024062234371, -0.025544514279826257)
# Creature at (-0.465649130142731, -0.03441024062234371, -0.025544514279826257) with fitness: -14.498960414959885
# Position after move: (-0.1980265840529101, -0.06315070451184582, -0.04682970519537091)
# ...

# %% [markdown]
# # Download best_creature

# %%
# Code to download the best_creatures.json file in Google Colab
from google.colab import files
files.download('best_creatures.json')
